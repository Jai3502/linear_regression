# %% [markdown]
# # python implementation of linear regession

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##  2 Generating random dataset

# %%
np.random.seed(42)
x = np.random.rand(50,1) * 100
y = 3.5 * x + np.random.rand(50,1) * 20

# %% [markdown]
# ## 3. creating and training linear regression model

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## 4 predicting Y values

# %%
Y_pred = model.predict(x)

# %% [markdown]
# # 5. visualizing the regression in line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x,y,color='blue',label='Actual Data')
plt.plot(x,Y_pred,color='red', linewidth=2, label='Linear Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression on random dataset')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 6. slope and intercept

# %%
print("slpoe (coefficient):", model.coef_[0][0])
print("intercept:", model.intercept_[0])
# Out:
# slpoe (coefficient): 3.513215329859616
# intercept: 9.29944849840004
